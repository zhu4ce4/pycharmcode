# %%
import requests
import pandas as pd

# %%
data=pd.read_excel('votes.xls','金融')
data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>支持</th>
#       <th>名称</th>
#     </tr>
#     <tr>
#       <th>排名</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>3360</td>
#       <td>常高新集团有限公司</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>870</td>
#       <td>广东国晖(天津)律师事务所</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>840</td>
#       <td>成都正福金融工程应用研究院</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>390</td>
#       <td>中国科学院沈阳自动化研究所</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>210</td>
#       <td>哈尔滨市飞光无人机科技有限公司</td>
#     </tr>
# ...

# %%
# Out:
# {'支持': [12935, 7330, 5225, 5045, 3950, 3485],
#  '名称': ['招商银行股份有限公司广州分行',
#   '捷信消费金融有限公司',
#   '汇丰环球客户服务(广东)有限公司',
#   '中国银行股份有限公司四川省分行',
#   '大连千海金资产管理有限公司',
#   '阳光保险集团股份有限公司']}

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>支持</th>
#       <th>名称</th>
#     </tr>
#     <tr>
#       <th>排名</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>12935</td>
#       <td>招商银行股份有限公司广州分行</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>7390</td>
#       <td>捷信消费金融有限公司</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5225</td>
#       <td>汇丰环球客户服务(广东)有限公司</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5045</td>
#       <td>中国银行股份有限公司四川省分行</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3950</td>
#       <td>大连千海金资产管理有限公司</td>
# ...
